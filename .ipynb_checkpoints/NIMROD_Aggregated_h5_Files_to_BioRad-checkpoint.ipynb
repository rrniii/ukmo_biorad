# %% [markdown]
# !conda run -n pyart_3_8_radar_group python -m ipykernel install --user --name radar-env

# %%
import matplotlib.pyplot as plt
import pyart
import netCDF4
import h5py as h5
from glob import glob
import os
import numpy as np
import cartopy.crs as ccrs
import warnings 
import time 
import cartopy.feature as cfeature
import cartopy.io.img_tiles as cimgt
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import rasterio
import matplotlib
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
#file='/gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/raw_h5_data/single-site/chenies/2021/20210709_polar_pl_radar05_aggregate.h5'
file='/gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/raw_h5_data/single-site/chenies/2025/20250816_polar_pl_radar05_aggregate.h5'

# %%
f = h5.File(file, 'r')

#'lp' or 'sp'
f['sp'].keys()

#sp is every 10 minutes
#lp is every 5 minutes
# Out:
# <KeysViewHDF5 ['0000', '0010', '0020', '0030', '0040', '0050', '0100', '0110', '0120', '0130', '0140', '0150', '0200', '0210', '0220', '0230', '0240', '0250', '0300', '0310', '0320', '0330', '0340', '0350', '0400', '0410', '0420', '0430', '0440', '0450', '0500', '0510', '0520', '0530', '0540', '0550', '0600', '0610', '0620', '0630', '0640', '0650', '0700', '0710', '0720', '0730', '0740', '0750', '0800', '0810', '0820', '0830', '0840', '0850', '0900', '0910', '0920', '0930', '0940', '0950', '1000', '1010', '1020', '1030', '1040', '1050', '1100', '1110', '1120', '1130', '1140', '1150', '1200', '1210', '1220', '1230', '1240', '1250', '1300', '1310', '1320', '1330', '1340', '1350', '1400', '1410', '1420', '1430', '1440', '1450', '1500', '1510', '1520', '1530', '1540', '1550', '1600', '1610', '1620', '1630', '1640', '1650', '1700', '1710', '1720', '1730', '1740', '1750', '1800', '1810', '1820', '1830', '1840', '1850', '1900', '1910', '1920', '1930', '1940', '1950', '2000', '2010', '2020', '2030', '2040', '2050', '2100', '2110', '2120', '2130', '2140', '2150', '2200', '2210', '2220', '2230', '2240', '2250', '2300', '2310', '2320', '2330', '2340', '2350']>

# %%
f['sp'].keys()
# Out:
# <KeysViewHDF5 ['0000', '0010', '0020', '0030', '0040', '0050', '0100', '0110', '0120', '0130', '0140', '0150', '0200', '0210', '0220', '0230', '0240', '0250', '0300', '0310', '0320', '0330', '0340', '0350', '0400', '0410', '0420', '0430', '0440', '0450', '0500', '0510', '0520', '0530', '0540', '0550', '0600', '0610', '0620', '0630', '0640', '0650', '0700', '0710', '0720', '0730', '0740', '0750', '0800', '0810', '0820', '0830', '0840', '0850', '0900', '0910', '0920', '0930', '0940', '0950', '1000', '1010', '1020', '1030', '1040', '1050', '1100', '1110', '1120', '1130', '1140', '1150', '1200', '1210', '1220', '1230', '1240', '1250', '1300', '1310', '1320', '1330', '1340', '1350', '1400', '1410', '1420', '1430', '1440', '1450', '1500', '1510', '1520', '1530', '1540', '1550', '1600', '1610', '1620', '1630', '1640', '1650', '1700', '1710', '1720', '1730', '1740', '1750', '1800', '1810', '1820', '1830', '1840', '1850', '1900', '1910', '1920', '1930', '1940', '1950', '2000', '2010', '2020', '2030', '2040', '2050', '2100', '2110', '2120', '2130', '2140', '2150', '2200', '2210', '2220', '2230', '2240', '2250', '2300', '2310', '2320', '2330', '2340', '2350']>

# %%
f['lp']['0110'].keys()
# Out:
# <KeysViewHDF5 ['dataset1', 'dataset2', 'dataset3', 'dataset4', 'dataset5', 'how', 'what', 'where']>

# %%
f['lp']['0110'].keys()
# Out:
# <KeysViewHDF5 ['dataset1', 'dataset2', 'dataset3', 'dataset4', 'dataset5', 'how', 'what', 'where']>

# %%
f['lp']['0110']['how'].attrs.keys()
# Out:
# <KeysViewHDF5 ['NI', 'RXlossH', 'RXlossV', 'TXtype', 'antgainH', 'antgainV', 'beamwH', 'beamwV', 'beamwidth', 'frequency', 'highprf', 'lowprf', 'nco_frequency', 'platform_type', 'polmode', 'poltyp', 'pulsewidth', 'radconstH', 'radconstV', 'radconstant', 'rxcalH_dBm', 'rxcalV_dBm', 'scan_count', 'simulated', 'software', 'sw_version', 'system', 'wavelength', 'zr_a', 'zr_b']>

# %%
f['lp']['0110']['what'].attrs.keys()
# Out:
# <KeysViewHDF5 ['date', 'object', 'source', 'source_local_site_number', 'source_wmo_site_number', 'time', 'version']>

# %%
f['lp']['0110']['where'].attrs.keys()
# Out:
# <KeysViewHDF5 ['elangles_map', 'height', 'lat', 'lon', 'source_local_grid_easting', 'source_local_grid_northing']>

# %%
f['lp']['0110']['dataset1'].keys()
# Out:
# <KeysViewHDF5 ['data1', 'data2', 'data3', 'data4', 'data5', 'data6', 'data7', 'how', 'quality1', 'quality2', 'what', 'where']>

# %%
f['lp']['0110']['dataset1']['where'].attrs.keys()
# Out:
# <KeysViewHDF5 ['a1gate', 'elangle', 'nbins', 'nrays', 'rscale', 'rstart']>

# %%
f['lp']['0110']['dataset1']['where'].attrs['rscale']
# Out:
# 600.0

# %%
f['lp']['0110']['dataset1']['where'].attrs['rscale']
# Out:
# 600.0

# %%
f['sp']['0110']['dataset1']['where'].attrs['rscale']
# Out:
# 600.0

# %%
f['lp']['1250']['dataset1']['how'].attrs.keys()
# Out:
# <KeysViewHDF5 ['RXnoiseH', 'RXnoiseV', 'TXpulsepower', 'antspeed', 'astart', 'azmethod', 'binmethod', 'binmethod_avg', 'elmethod', 'endepochs', 'injectlossH', 'injectlossV', 'scan_index', 'startazA', 'startelA', 'startepochs', 'stopazA', 'stopelA']>

# %%
f['lp']['1250']['dataset1']['how'].attrs.keys()
# Out:
# <KeysViewHDF5 ['RXnoiseH', 'RXnoiseV', 'TXpulsepower', 'antspeed', 'astart', 'azmethod', 'binmethod', 'binmethod_avg', 'elmethod', 'endepochs', 'injectlossH', 'injectlossV', 'scan_index', 'startazA', 'startelA', 'startepochs', 'stopazA', 'stopelA']>

# %%
f['lp']['1250']['dataset5']['how'].attrs['stopelA']
# Out:
# array([4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4.])

# %%
f['lp']['1250']['dataset1']['how'].attrs['stopazA']
# Out:
# array([  0.5 ,   1.5 ,   2.49,   3.51,   4.51,   5.5 ,   6.5 ,   7.5 ,
#          8.49,   9.5 ,  10.5 ,  11.49,  12.5 ,  13.5 ,  14.5 ,  15.5 ,
#         16.49,  17.49,  18.5 ,  19.5 ,  20.49,  21.49,  22.5 ,  23.48,
#         24.49,  25.49,  26.49,  27.5 ,  28.49,  29.49,  30.5 ,  31.49,
#         32.49,  33.49,  34.5 ,  35.5 ,  36.49,  37.49,  38.49,  39.5 ,
#         40.5 ,  41.49,  42.49,  43.49,  44.49,  45.5 ,  46.5 ,  47.5 ,
#         48.51,  49.49,  50.49,  51.49,  52.5 ,  53.5 ,  54.5 ,  55.49,
#         56.48,  57.49,  58.5 ,  59.5 ,  60.5 ,  61.5 ,  62.5 ,  63.5 ,
#         64.49,  65.5 ,  66.49,  67.5 ,  68.49,  69.5 ,  70.5 ,  71.5 ,
#         72.49,  73.49,  74.49,  75.48,  76.5 ,  77.5 ,  78.5 ,  79.5 ,
#         80.5 ,  81.5 ,  82.49,  83.49,  84.49,  85.49,  86.5 ,  87.48,
#         88.49,  89.49,  90.49,  91.5 ,  92.5 ,  93.5 ,  94.51,  95.5 ,
#         96.5 ,  97.51,  98.5 ,  99.49, 100.49, 101.49, 102.5 , 103.51,
#        104.51, 105.49, 106.5 , 107.5 , 108.5 , 109.5 , 110.49, 111.5 ,
#        112.49, 113.49, 114.5 , 115.49, 116.49, 117.5 , 118.5 , 119.5 ,
#        120.5 , 121.49, 122.48, 123.49, 124.5 , 125.49, 126.48, 127.49,
#        128.49, 129.49, 130.49, 131.5 , 132.5 , 133.49, 134.5 , 135.5 ,
#        136.49, 137.5 , 138.5 , 139.5 , 140.5 , 141.49, 142.5 , 143.49,
#        144.5 , 145.51, 146.5 , 147.5 , 148.5 , 149.49, 150.49, 151.49,
#        152.49, 153.5 , 154.5 , 155.5 , 156.48, 157.5 , 158.5 , 159.49,
#        160.5 , 161.5 , 162.49, 163.49, 164.49, 165.5 , 166.5 , 167.49,
#        168.49, 169.48, 170.49, 171.49, 172.49, 173.5 , 174.49, 175.49,
#        176.5 , 177.5 , 178.5 , 179.5 , 180.5 , 181.5 , 182.49, 183.5 ,
#        184.5 , 185.5 , 186.49, 187.5 , 188.5 , 189.49, 190.49, 191.5 ,
#        192.49, 193.49, 194.49, 195.49, 196.5 , 197.49, 198.5 , 199.5 ,
#        200.49, 201.51, 202.49, 203.49, 204.48, 205.49, 206.49, 207.49,
#        208.49, 209.49, 210.49, 211.5 , 212.5 , 213.49, 214.49, 215.49,
#        216.49, 217.49, 218.5 , 219.5 , 220.48, 221.5 , 222.49, 223.5 ,
#        224.5 , 225.49, 226.5 , 227.5 , 228.5 , 229.5 , 230.49, 231.5 ,
#        232.5 , 233.49, 234.51, 235.51, 236.5 , 237.5 , 238.51, 239.5 ,
#        240.5 , 241.5 , 242.5 , 243.5 , 244.5 , 245.49, 246.49, 247.49,
#        248.49, 249.5 , 250.49, 251.49, 252.5 , 253.49, 254.5 , 255.49,
#        256.49, 257.49, 258.49, 259.5 , 260.49, 261.48, 262.49, 263.49,
#        264.5 , 265.49, 266.49, 267.5 , 268.5 , 269.5 , 270.49, 271.5 ,
#        272.5 , 273.51, 274.51, 275.49, 276.49, 277.51, 278.5 , 279.51,
#        280.51, 281.49, 282.49, 283.51, 284.49, 285.49, 286.5 , 287.5 ,
#        288.5 , 289.5 , 290.5 , 291.49, 292.49, 293.5 , 294.49, 295.49,
#        296.5 , 297.5 , 298.5 , 299.49, 300.49, 301.49, 302.49, 303.49,
#        304.49, 305.5 , 306.49, 307.49, 308.49, 309.49, 310.49, 311.5 ,
#        312.5 , 313.5 , 314.5 , 315.49, 316.51, 317.5 , 318.5 , 319.5 ,
#        320.51, 321.49, 322.5 , 323.5 , 324.5 , 325.5 , 326.49, 327.49,
#        328.49, 329.49, 330.49, 331.5 , 332.49, 333.5 , 334.49, 335.49,
#        336.49, 337.49, 338.49, 339.49, 340.5 , 341.5 , 342.48, 343.49,
#        344.49, 345.49, 346.49, 347.49, 348.49, 349.48, 350.49, 351.49,
#        352.5 , 353.5 , 354.5 , 355.49, 356.49, 357.49, 358.49, 359.49])

# %%
f['lp']['1250']['how'].attrs['pulsewidth']
# Out:
# 2e-06

# %%
f['lp']['1250']['dataset1']['what'].attrs.keys()
# Out:
# <KeysViewHDF5 ['enddate', 'endtime', 'product', 'startdate', 'starttime']>

# %%
f['lp']['0110']['dataset1']['where'].attrs.keys()
# Out:
# <KeysViewHDF5 ['a1gate', 'elangle', 'nbins', 'nrays', 'rscale', 'rstart']>

# %%
f['lp']['0110']['dataset1']['where'].attrs['rscale']
# Out:
# 600.0

# %%
f['lp']['0110']['dataset1']['where'].attrs['nbins']
# Out:
# 425

# %%
f['sp']['1250']['dataset1']['data1'].keys()
# Out:
# <KeysViewHDF5 ['data', 'how', 'what']>

# %%
f['sp']['1250']['dataset1']['data1']['data'][:]
# Out:
# array([[  0., 344., 608., ..., 472., 469., 468.],
#        [  0., 459., 506., ..., 468., 467., 465.],
#        [  0., 511., 440., ..., 469., 471., 468.],
#        ...,
#        [  0., 444., 431., ..., 472., 465., 469.],
#        [  0., 400., 545., ..., 466., 470., 473.],
#        [  0., 380., 601., ..., 470., 468., 472.]])

# %%
f['sp']['1250']['dataset1']['data1']['what'].attrs.keys()
# Out:
# <KeysViewHDF5 ['gain', 'nodata', 'offset', 'quantity', 'undetect']>

# %%
pulse_selector='sp'
data_selector='data1'
print(f[pulse_selector]['0000']['dataset1'][data_selector]['what'].attrs['gain'])
print(f[pulse_selector]['0000']['dataset1'][data_selector]['what'].attrs['offset'])
print(f[pulse_selector]['0000']['dataset1'][data_selector]['what'].attrs['quantity'])
# Out:
# 0.1
# -32.0
# DBZH

# %% [markdown]
# # Function to Save Data in bioRad Compatible Format

# %%
import h5py
import shutil

import os
#os.remove('test.h5')
# Specify the file names and the dataset name
#input_file = '/gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/raw_h5_data/single-site/chenies/2021/20210709_polar_pl_radar05_aggregate.h5'
input_file='/gws/nopw/j04/ncas_radar_vol2/avocet/ukmo-nimrod/raw_h5_data_final/single-site/chenies/2025/20250720_polar_pl_radar05_aggregate.h5'
output_file = '20250720_polar_pl_radar05_aggregate_sp_0000.h5'
group_name = 'sp/0000/'
dataset_name = '0000'

# Open the existing H5 file in read mode
with h5py.File(input_file, 'r') as h5file:
    # Open the output H5 file in append mode ('a' mode ensures that existing data is preserved)
    with h5py.File(output_file, 'w') as new_h5file:

    # Datasets in selected type and time group
    # Access the specific group by name
        group = h5file[group_name]
        # Function to recursively copy datasets to the root level
        def copy_datasets_to_root(group, base_name=""):
            for item_name, item in group.items():
                print('name is:'+item_name)
                print(item)
                full_item_name = f"{base_name}{item_name}"
                if isinstance(item, h5py.Dataset):
                    # Copy dataset to the root of the new file
                    new_h5file.create_dataset(full_item_name, data=item[:])
                elif isinstance(item, h5py.Group):
                    if item_name=='where' or 'what':
                        h5file.copy(h5file[group_name+full_item_name], new_h5file, name=full_item_name)
                        
                    # Recursively copy items in the sub-group, flattening the hierarchy
                    else:
                        copy_datasets_to_root(item, base_name=f"{full_item_name}/")
    
        # Start copying from the specified group
        copy_datasets_to_root(group)

    print(f"Datasets from group '{group_name}' and root attributes have been saved directly to '{output_file}' without the group hierarchy.")
# Out:
# name is:dataset1
# <HDF5 group "/sp/0000/dataset1" (13 members)>
# name is:dataset2
# <HDF5 group "/sp/0000/dataset2" (13 members)>
# name is:dataset3
# <HDF5 group "/sp/0000/dataset3" (13 members)>
# name is:dataset4
# <HDF5 group "/sp/0000/dataset4" (13 members)>
# name is:dataset5
# <HDF5 group "/sp/0000/dataset5" (13 members)>
# name is:dataset6
# <HDF5 group "/sp/0000/dataset6" (13 members)>
# name is:how
# <HDF5 group "/sp/0000/how" (0 members)>
# name is:what
# <HDF5 group "/sp/0000/what" (0 members)>
# name is:where
# <HDF5 group "/sp/0000/where" (0 members)>
# Datasets from group 'sp/0000/' and root attributes have been saved directly to '20240729_polar_pl_radar05_aggregate_sp_0000.h5' without the group hierarchy.

# %% [markdown]
# ## Single File Looper

# %%
import re
from pathlib import Path
import h5py
import numpy as np
import scipy.ndimage as spnd

# ----------------------------
# ODIM helpers
# ----------------------------
def _copy_attrs(src_obj, dst_obj):
    for k, v in src_obj.attrs.items():
        dst_obj.attrs[k] = v

def _ensure_group(parent, name):
    return parent[name] if name in parent else parent.create_group(name)

def _dataset_names(h5f):
    return sorted([k for k in h5f.keys() if k.startswith('dataset')])

def _discover_style_and_template(ds_group):
    """
    Detect storage style of dataY:
      - 'group' style: datasetX/dataY (Group) with 'data' (Dataset) + 'what' (Group)
      - 'dataset' style: datasetX/dataY (Dataset) directly
    Also return a template of IMAGE attrs to copy (CLASS, IMAGE_VERSION).
    """
    for name, obj in ds_group.items():
        if not name.startswith('data'): 
            continue
        if isinstance(obj, h5py.Group) and 'data' in obj:
            tmpl = {}
            for key in ('CLASS', 'IMAGE_VERSION'):
                if key in obj['data'].attrs:
                    tmpl[key] = obj['data'].attrs[key]
            return 'group', tmpl
        if isinstance(obj, h5py.Dataset):
            tmpl = {}
            for key in ('CLASS', 'IMAGE_VERSION'):
                if key in obj.attrs:
                    tmpl[key] = obj.attrs[key]
            return 'dataset', tmpl
    return 'group', {}

def _iter_data_items(ds_group):
    """
    Yield (name, container, data_dset, style).
    - style 'group': container is dataY group; data_dset is container['data']
    - style 'dataset': container is the dataset; data_dset is container
    """
    for name, obj in ds_group.items():
        if not name.startswith('data'):
            continue
        if isinstance(obj, h5py.Group) and 'data' in obj:
            yield name, obj, obj['data'], 'group'
        elif isinstance(obj, h5py.Dataset):
            yield name, obj, obj, 'dataset'

def _read_quantity(container, data_dset, style):
    if style == 'group':
        q = _ensure_group(container, 'what').attrs.get('quantity', None)
    else:
        q = data_dset.attrs.get('quantity', None)
    if isinstance(q, (bytes, np.bytes_)):
        q = q.decode('utf-8', 'ignore')
    return q

def _read_gain_offset(container, data_dset, style, default_gain=1.0, default_offset=0.0):
    if style == 'group':
        what = _ensure_group(container, 'what')
        gain = what.attrs.get('gain', default_gain)
        offset = what.attrs.get('offset', default_offset)
    else:
        gain = data_dset.attrs.get('gain', default_gain)
        offset = data_dset.attrs.get('offset', default_offset)
    return float(gain), float(offset)

def _read_nodata(container, data_dset, style):
    if style == 'group':
        what = _ensure_group(container, 'what')
        if 'nodata' in what.attrs: return what.attrs['nodata']
        if 'undetect' in what.attrs: return what.attrs['undetect']
    else:
        if 'nodata' in data_dset.attrs: return data_dset.attrs['nodata']
        if 'undetect' in data_dset.attrs: return data_dset.attrs['undetect']
    # sensible default by dtype
    dt = data_dset.dtype
    if np.issubdtype(dt, np.floating): return -9999.0
    if np.issubdtype(dt, np.signedinteger): return np.iinfo(dt).min
    if np.issubdtype(dt, np.unsignedinteger): return np.iinfo(dt).max
    return -9999.0

def _write_nodata(container, data_dset, style, value):
    if style == 'group':
        what = _ensure_group(container, 'what')
        what.attrs['nodata'] = value
        if 'undetect' not in what.attrs:
            what.attrs['undetect'] = value
    else:
        data_dset.attrs['nodata'] = value
        if 'undetect' not in data_dset.attrs:
            data_dset.attrs['undetect'] = value

def _choose_fill_for_dtype(dtype):
    if np.issubdtype(dtype, np.floating): return -9999.0
    if np.issubdtype(dtype, np.signedinteger): return np.iinfo(dtype).min
    if np.issubdtype(dtype, np.unsignedinteger): return np.iinfo(dtype).max
    return -9999.0

def _next_data_name(ds_group):
    n = 1
    while f"data{n}" in ds_group:
        n += 1
    return f"data{n}"

def _find_reflectivity_data(ds_group):
    """
    Find a reflectivity-like dataY in datasetX by 'what/quantity'.
    Accepts DBZH, DBZ, TH, ZHH, ZH (case-insensitive), or anything containing 'DBZ'.
    Returns (name, container, data_dset, style, gain, offset, nodata).
    """
    candidates = []
    for name, container, data_dset, style in _iter_data_items(ds_group):
        q = _read_quantity(container, data_dset, style)
        if q is None:
            continue
        qU = str(q).upper()
        ok = (qU in ('DBZH', 'DBZ', 'TH', 'ZHH', 'ZH')) or ('DBZ' in qU)
        if ok:
            gain, offset = _read_gain_offset(container, data_dset, style)
            nodata = _read_nodata(container, data_dset, style)
            candidates.append((name, container, data_dset, style, gain, offset, nodata, qU))
    # prefer explicit DBZH > DBZ > others
    prio = {'DBZH': 0, 'DBZ': 1}
    if candidates:
        candidates.sort(key=lambda t: prio.get(t[7], 9))
        return candidates[0]
    return None

def _compute_geometry(od, ds_group):
    """
    Build range [km] and gate_altitude [m] arrays from ODIM 'where' and root 'where'.
    """
    root_where = od.get('where', None)
    radar_h = float(root_where.attrs.get('height', 0.0)) if root_where is not None else 0.0

    where = ds_group.get('where', None)
    if where is None:
        raise KeyError("datasetX/where missing")

    nbins = int(where.attrs['nbins'])
    nrays = int(where.attrs['nrays'])
    rstart = float(where.attrs.get('rstart', 0.0))   # meters
    rscale = float(where.attrs['rscale'])            # meters

    # elevation angle: prefer 'elangle' (deg). If absent, default small angle.
    el = where.attrs.get('elangle', None)
    if isinstance(el, (bytes, np.bytes_)):
        el = el.decode('utf-8', 'ignore')
    if el is None:
        el_deg = 0.5
    else:
        el_deg = float(el)
    el_rad = np.deg2rad(el_deg)

    rng_m = rstart + np.arange(nbins, dtype=np.float64) * rscale
    rng_km = rng_m / 1000.0

    # Simple flat-earth vertical projection; matches your earlier approach via Py-ART gate_altitude
    gate_alt = radar_h + np.sin(el_rad) * rng_m
    gate_alt_2d = np.tile(gate_alt, nrays).reshape(nrays, nbins)

    return rng_km, gate_alt_2d, nrays, nbins

def _estimate_snrh_from_odim(od, ds_group, range_limit_km=50.0, height_limit_m=17500.0):
    """
    Using an ODIM datasetX group, compute SNRH [dB] as per your algorithm.
    Returns (noise_estimate_dBZ_Plin, SNRH_array[ nrays x nbins ], mask_invalid).
    """
    ref_info = _find_reflectivity_data(ds_group)
    if ref_info is None:
        raise KeyError("No reflectivity-like ODIM quantity found (expected DBZH/DBZ/TH/ZHH/ZH).")
    name, container, data_dset, style, gain, offset, nodata, qU = ref_info

    rng_km, gate_alt_2d, nrays, nbins = _compute_geometry(od, ds_group)

    raw = data_dset[...]
    # Convert to float dBZ using gain/offset
    dBZ = raw.astype(np.float64) * gain + offset

    # Mask nodata/undetect and very low fill values like -32 dBZ (Met Office fill)
    nodata_cast = np.array(nodata).astype(raw.dtype)
    mask = (raw == nodata_cast)
    dBZ = np.ma.array(dBZ, mask=mask)
    dBZ = np.ma.masked_less_equal(dBZ, -32.0)

    # Mask strong echoes for noise estimation
    dBZ_highmask = np.ma.masked_greater_equal(dBZ, 30.0)

    # Range 2D (km) and noise-location mask
    rng2d = np.tile(rng_km, nrays).reshape(nrays, nbins)
    noise_loc = (gate_alt_2d > height_limit_m) & (rng2d > range_limit_km) & (~dBZ_highmask.mask)

    # Remove range correction and estimate noise (mean over gates flagged as noise)
    dBZ_Plin = dBZ - 20.0 * np.log10(rng_km)  # broadcasts over rays
    dBZ_Plin_M = np.where(noise_loc, dBZ_Plin, np.nan)
    noise_est = np.round(np.nanmean(np.nanmean(dBZ_Plin_M, axis=0)), 2)

    # Linearize, subtract noise, guard smalls, back to dB, subtract noise_est again per your formula
    lin_noise = np.power(10.0, 0.1 * noise_est)
    signal = np.power(10.0, 0.1 * dBZ_Plin) - lin_noise
    signal = np.where(signal <= 1e-12, 1e-12, signal)
    SNRH = 10.0 * np.log10(signal) - noise_est

    return noise_est, np.ma.masked_invalid(SNRH), dBZ.mask

def _add_snrh_to_ds(ds_group, snrh_array, tmpl_attrs):
    """
    Add SNRH as a new dataN, matching the file's style (group/dataset).
    Returns the created dataN name.
    """
    style, _ = _discover_style_and_template(ds_group)
    data_name = _next_data_name(ds_group)
    data = np.array(np.ma.filled(snrh_array, np.nan), dtype=np.float32)

    if style == 'group':
        g = ds_group.create_group(data_name)
        d = g.create_dataset('data', data=data, dtype='f4')
        for k, v in tmpl_attrs.items():
            d.attrs[k] = v
        what = g.create_group('what')
        what.attrs['quantity'] = 'SNRH'
        what.attrs['gain']     = np.float32(1.0)
        what.attrs['offset']   = np.float32(0.0)
        what.attrs['nodata']   = np.float32(-9999.0)
        what.attrs['undetect'] = np.float32(-9999.0)
    else:
        d = ds_group.create_dataset(data_name, data=data, dtype='f4')
        for k, v in tmpl_attrs.items():
            d.attrs[k] = v
        d.attrs['quantity']  = 'SNRH'
        d.attrs['gain']      = np.float32(1.0)
        d.attrs['offset']    = np.float32(0.0)
        d.attrs['nodata']    = np.float32(-9999.0)
        d.attrs['undetect']  = np.float32(-9999.0)

    return data_name

def _apply_gate_to_ds(ds_group, gate_included, exclude_names):
    """
    Gate every dataY in this dataset: set excluded gates to nodata (or create one).
    Do not touch entries in exclude_names (i.e., SNRH itself).
    """
    for name, container, data_dset, style in _iter_data_items(ds_group):
        if name in exclude_names:
            continue
        if data_dset.shape != gate_included.shape:
            continue
        # find or create nodata
        nodata = _read_nodata(container, data_dset, style)
        if nodata is None:
            nodata = _choose_fill_for_dtype(data_dset.dtype)
        arr = data_dset[...]
        nod = np.array(nodata).astype(arr.dtype)
        arr = np.array(arr, copy=True)
        arr[~gate_included] = nod
        data_dset[...] = arr
        _write_nodata(container, data_dset, style, nod)

# ----------------------------
# Main pipeline
# ----------------------------
def process_file(input_file: str):
    in_path = Path(input_file)
    if not in_path.exists():
        raise FileNotFoundError(f"Input file not found: {in_path}")

    m = re.search(r"(?P<date>\d{8}).*?_radar(?P<radar>\d{2})", in_path.name)
    if not m:
        raise ValueError("Filename must contain 'YYYYMMDD' and 'radarNN'.")
    date_str = m.group("date")
    radar_num = m.group("radar")

    # Build output dir: raw_h5_data -> biorad, add /<YYYYMMDD>/
    parts = list(in_path.parts)
    if "raw_h5_data" not in parts:
        raise ValueError("Expected 'raw_h5_data' in input path.")
    parts[parts.index("raw_h5_data")] = "biorad"
    out_base = Path(*parts[:-1])
    day_dir = out_base / date_str
    day_dir.mkdir(parents=True, exist_ok=True)

    # 1) Split: write per-time ODIM files with sp/<time> lifted to root
    with h5py.File(in_path, "r") as src:
        if "sp" not in src:
            raise KeyError("Group 'sp' not found in input file.")
        sp_group = src["sp"]

        for time_key, time_grp in sp_group.items():
            if not isinstance(time_grp, h5py.Group):
                continue

            out_name = f"{date_str}_polar_pl_radar{radar_num}_aggregate_sp_{time_key}.h5"
            odim_out = day_dir / out_name

            # Write lifted ODIM file
            with h5py.File(odim_out, "w") as dst:
                _copy_attrs(src, dst)
                _copy_attrs(time_grp, dst)
                for child_name, child in time_grp.items():
                    src.copy(child, dst, name=child_name)
            print(f"[ODIM] wrote: {odim_out}")

            # 2) Process each datasetX directly (no Py-ART)
            with h5py.File(odim_out, "a") as od:
                ds_names = _dataset_names(od)

                for ds_name in ds_names:
                    ds_group = od[ds_name]

                    # Compute SNRH from ODIM
                    try:
                        noise_est, SNRH, _mask_ref = _estimate_snrh_from_odim(od, ds_group)
                    except KeyError as e:
                        print(f"[WARN] {odim_out} :: {ds_name}: {e}. Skipping this dataset.")
                        continue

                    # Gate definition (despeckle + thresholds + median smoothing)
                    # thresholding
                    snr_data = np.ma.filled(SNRH, np.nan)
                    valid = ~np.isnan(snr_data)
                    above_minus2 = valid & (snr_data > -2.0)
                    above_10 = valid & (snr_data >= 10.0)

                    # despeckle on above_minus2 blobs
                    structure = np.ones((3, 3), dtype=bool)
                    labeled, nlab = spnd.label(above_minus2, structure=structure)
                    sizes = np.bincount(labeled.ravel())
                    remove_small = np.isin(labeled, np.where(sizes < 25)[0])
                    despeckled = above_minus2 & (~remove_small)

                    included = despeckled | above_10
                    included = spnd.median_filter(included.astype(np.uint8), size=5).astype(bool)

                    # Add SNRH as native ODIM dataN
                    _, tmpl = _discover_style_and_template(ds_group)
                    snr_name = _add_snrh_to_ds(ds_group, SNRH, tmpl)

                    # Apply gate to all other data* in this dataset
                    _apply_gate_to_ds(ds_group, included, exclude_names={snr_name})

                    # provenance
                    _ensure_group(ds_group, 'what').attrs['snrh_noise_estimate_dBZ_Plin'] = np.float32(noise_est)

                    print(f"[ODIM updated] {odim_out} :: {ds_name} (+ {snr_name}=SNRH; gated others)")

# %%
INPUT = "/gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/raw_h5_data/single-site/chenies/2025/20250816_polar_pl_radar05_aggregate.h5"
process_file(INPUT)
# Out:
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0000.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0000.h5 :: dataset1 (+ data8=SNRH; gated others)
# /tmp/ipykernel_880/3817696838.py:204: RuntimeWarning: divide by zero encountered in log10
#   dBZ_Plin = dBZ - 20.0 * np.log10(rng_km)  # broadcasts over rays
# /tmp/ipykernel_880/3817696838.py:206: RuntimeWarning: Mean of empty slice
#   noise_est = np.round(np.nanmean(np.nanmean(dBZ_Plin_M, axis=0)), 2)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0000.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0000.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0000.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0000.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0000.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0010.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0010.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0010.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0010.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0010.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0010.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0010.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0020.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0020.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0020.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0020.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0020.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0020.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0020.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0030.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0030.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0030.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0030.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0030.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0030.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0030.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0040.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0040.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0040.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0040.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0040.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0040.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0040.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0050.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0050.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0050.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0050.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0050.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0050.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0050.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0100.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0100.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0100.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0100.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0100.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0100.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0100.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0110.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0110.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0110.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0110.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0110.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0110.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0110.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0120.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0120.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0120.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0120.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0120.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0120.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0120.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0130.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0130.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0130.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0130.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0130.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0130.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0130.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0140.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0140.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0140.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0140.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0140.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0140.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0140.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0150.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0150.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0150.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0150.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0150.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0150.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0150.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0200.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0200.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0200.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0200.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0200.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0200.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0200.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0210.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0210.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0210.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0210.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0210.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0210.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0210.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0220.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0220.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0220.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0220.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0220.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0220.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0220.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0230.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0230.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0230.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0230.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0230.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0230.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0230.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0240.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0240.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0240.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0240.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0240.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0240.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0240.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0250.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0250.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0250.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0250.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0250.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0250.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0250.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0300.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0300.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0300.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0300.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0300.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0300.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0300.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0310.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0310.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0310.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0310.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0310.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0310.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0310.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0320.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0320.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0320.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0320.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0320.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0320.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0320.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0330.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0330.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0330.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0330.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0330.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0330.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0330.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0340.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0340.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0340.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0340.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0340.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0340.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0340.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0350.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0350.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0350.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0350.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0350.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0350.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0350.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0400.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0400.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0400.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0400.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0400.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0400.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0400.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0410.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0410.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0410.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0410.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0410.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0410.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0410.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0420.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0420.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0420.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0420.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0420.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0420.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0420.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0430.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0430.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0430.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0430.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0430.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0430.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0430.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0440.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0440.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0440.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0440.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0440.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0440.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0440.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0450.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0450.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0450.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0450.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0450.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0450.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0450.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0500.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0500.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0500.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0500.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0500.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0500.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0500.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0510.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0510.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0510.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0510.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0510.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0510.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0510.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0520.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0520.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0520.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0520.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0520.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0520.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0520.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0530.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0530.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0530.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0530.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0530.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0530.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0530.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0540.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0540.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0540.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0540.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0540.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0540.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0540.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0550.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0550.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0550.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0550.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0550.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0550.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0550.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0600.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0600.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0600.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0600.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0600.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0600.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0600.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0610.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0610.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0610.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0610.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0610.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_0610.h5 :: dataset5 (+ data8=SNRH; gated others)
# ...
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2150.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2150.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2150.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2150.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2200.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2200.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2200.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2200.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2200.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2200.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2200.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2210.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2210.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2210.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2210.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2210.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2210.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2210.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2220.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2220.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2220.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2220.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2220.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2220.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2220.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2230.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2230.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2230.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2230.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2230.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2230.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2230.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2240.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2240.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2240.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2240.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2240.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2240.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2240.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2250.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2250.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2250.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2250.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2250.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2250.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2250.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2300.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2300.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2300.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2300.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2300.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2300.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2300.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2310.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2310.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2310.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2310.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2310.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2310.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2310.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2320.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2320.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2320.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2320.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2320.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2320.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2320.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2330.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2330.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2330.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2330.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2330.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2330.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2330.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2340.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2340.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2340.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2340.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2340.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2340.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2340.h5 :: dataset6 (+ data8=SNRH; gated others)
# [ODIM] wrote: /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2350.h5
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2350.h5 :: dataset1 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2350.h5 :: dataset2 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2350.h5 :: dataset3 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2350.h5 :: dataset4 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2350.h5 :: dataset5 (+ data8=SNRH; gated others)
# [ODIM updated] /gws/nopw/j04/ncas_radar_vol3/ukmo-nimrod/biorad/single-site/chenies/2025/20250816/20250816_polar_pl_radar05_aggregate_sp_2350.h5 :: dataset6 (+ data8=SNRH; gated others)

# %% [markdown]
# # Function to Read NIMROD Aggregated Files

# %%
"""
Routines for reading NIMROD ODIM_H5 Aggregated files.

"""

import datetime

import numpy as np
try:
    import h5py
    _H5PY_AVAILABLE = True
except ImportError:
    _H5PY_AVAILABLE = False

from pyart.config import FileMetadata, get_fillvalue
from pyart.io.common import make_time_unit_str, _test_arguments
from pyart.core.radar import Radar
from pyart.exceptions import MissingOptionalDependency


ODIM_H5_FIELD_NAMES = {
    'TH': 'total_power',        # uncorrected reflectivity, horizontal
    'TV': 'total_power',        # uncorrected reflectivity, vertical
    'DBZH': 'reflectivity',     # corrected reflectivity, horizontal
    'DBZV': 'reflectivity',     # corrected reflectivity, vertical
    'ZDR': 'differential_reflectivity',     # differential reflectivity
    'RHOHV': 'cross_correlation_ratio',
    'LDR': 'linear_polarization_ratio',
    'PHIDP': 'differential_phase',
    'KDP': 'specific_differential_phase',
    'SQI': 'normalized_coherent_power',
    'SNR': 'signal_to_noise_ratio',
    'VRAD': 'velocity', # radial velocity, marked for deprecation in ODIM HDF5 2.2
    'VRADH': 'velocity', # radial velocity, horizontal polarisation
    'VRADV': 'velocity', # radial velocity, vertical polarisation
    'WRAD': 'spectrum_width',
    'QIND': 'quality_index',
    'CI': 'clutter_index', #Add for NIMROD files
    'LONG_RANGE_NOISE_DBC_H': 'LONG_RANGE_NOISE_DBC_H', #Add for NIMROD files
    'LONG_RANGE_NOISE_DBC_V': 'LONG_RANGE_NOISE_DBC_V', #Add for NIMROD files
}


def read_nimrod_aggregated_odim_h5(filename,data_type, time, field_names=None, additional_metadata=None,
                 file_field_names=False, exclude_fields=None,
                 include_fields=None, **kwargs):
    """
    Read a NIMRD ODIM_H5 Aggregated file.

    Parameters
    ----------
    filename : str
        Name of the ODIM_H5 file to read.
    data_type : str
        lp (long pulse) or sp (short pulse) data to be read  #Need to expand to read vertical
    time : str
        string with the format hhmm that split the day into 144 ten minute chunks for sp data 
        or 288 5 minute chunks for lp data from 0000 to 2350. 
        Each period has been aggregated to make single volume.   
    field_names : dict, optional
        Dictionary mapping ODIM_H5 field names to radar field names. If a
        data type found in the file does not appear in this dictionary or has
        a value of None it will not be placed in the radar.fields dictionary.
        A value of None, the default, will use the mapping defined in the
        Py-ART configuration file.
    additional_metadata : dict of dicts, optional
        Dictionary of dictionaries to retrieve metadata from during this read.
        This metadata is not used during any successive file reads unless
        explicitly included.  A value of None, the default, will not
        introduct any addition metadata and the file specific or default
        metadata as specified by the Py-ART configuration file will be used.
    file_field_names : bool, optional
        True to use the MDV data type names for the field names. If this
        case the field_names parameter is ignored. The field dictionary will
        likely only have a 'data' key, unless the fields are defined in
        `additional_metadata`.
    exclude_fields : list or None, optional
        List of fields to exclude from the radar object. This is applied
        after the `file_field_names` and `field_names` parameters. Set
        to None to include all fields specified by include_fields.
    include_fields : list or None, optional
        List of fields to include from the radar object. This is applied
        after the `file_field_names` and `field_names` parameters. Set
        to None to include all fields not specified by exclude_fields.


    Returns
    -------
    radar : Radar
        Radar object containing data from ODIM_H5 file.

    """
    
    # TODO before moving to pyart.io
    # * unit test
    # * add default field mapping, etc to default config
    # * auto-detect file type with pyart.io.read function
    # * instrument parameters
    # * add additional checks for HOW attributes
    # * support for other objects (SCAN, XSEC)

    # check that h5py is available
    if not _H5PY_AVAILABLE:
        raise MissingOptionalDependency(
            "h5py is required to use read_odim_h5 but is not installed")

    # test for non empty kwargs
    _test_arguments(kwargs)

    # create metadata retrieval object
    if field_names is None:
        field_names = ODIM_H5_FIELD_NAMES
    filemetadata = FileMetadata('odim_h5', field_names, additional_metadata,
                                file_field_names, exclude_fields,
                                include_fields)

    # open the file
    with h5py.File(filename, 'r') as hfile:
        hfile=hfile[data_type][time]
        odim_object = _to_str(hfile['what'].attrs['object'])
        if odim_object not in ['PVOL', 'SCAN', 'ELEV', 'AZIM']:
            raise NotImplementedError(
                'object: %s not implemented.' % (odim_object))

        # determine the number of sweeps by the number of groups which
        # begin with dataset
        datasets = [k for k in hfile if k.startswith('dataset')]
        datasets.sort(key=lambda x: int(x[7:]))
        
        #Added to remove vert scans from NIMROD aggregated data as they are a different resolution
        for d in datasets:
            if hfile[d]['where'].attrs['elangle']>89.0:
                datasets.remove(d)
        
        
        nsweeps = len(datasets)

        # latitude, longitude and altitude
        latitude = filemetadata('latitude')
        longitude = filemetadata('longitude')
        altitude = filemetadata('altitude')

        h_where = hfile['where'].attrs
        latitude['data'] = np.array([h_where['lat']], dtype='float64')
        longitude['data'] = np.array([h_where['lon']], dtype='float64')
        altitude['data'] = np.array([h_where['height']], dtype='float64')

        # metadata
        metadata = filemetadata('metadata')
        metadata['instrument_name']=_get_radar_name_from_radar_numer(hfile['what'].attrs['source_local_site_number'])
        metadata['source'] = _to_str(hfile['what'].attrs['source'])
        metadata['original_container'] = 'ukmo_nimrod_aggregated_odim_h5'
        metadata['odim_conventions'] = _to_str(hfile.attrs['Conventions'])

        h_what = hfile['what'].attrs
        metadata['version'] = 'nimrod_test'#_to_str(h_what['version']) ####Need to talk to josh about it
        metadata['source'] = _to_str(h_what['source'])

        try:
            ds1_how = hfile[datasets[0]]['how'].attrs
        except KeyError:
            # if no how group exists mock it with an empty dictionary
            ds1_how = {}
        if 'system' in ds1_how:
            metadata['system'] = ds1_how['system']
        if 'software' in ds1_how:
            metadata['software'] = ds1_how['software']
        if 'sw_version' in ds1_how:
            metadata['sw_version'] = ds1_how['sw_version']

        # sweep_start_ray_index, sweep_end_ray_index
        sweep_start_ray_index = filemetadata('sweep_start_ray_index')
        sweep_end_ray_index = filemetadata('sweep_end_ray_index')

        if odim_object in ['AZIM', 'SCAN', 'PVOL']:
            rays_per_sweep = [
                int(hfile[d]['where'].attrs['nrays']) for d in datasets]
        elif odim_object == 'ELEV':
            rays_per_sweep = [
                int(hfile[d]['where'].attrs['angles'].size) for d in datasets]
        total_rays = sum(rays_per_sweep)
        ssri = np.cumsum(np.append([0], rays_per_sweep[:-1])).astype('int32')
        seri = np.cumsum(rays_per_sweep).astype('int32') - 1
        sweep_start_ray_index['data'] = ssri
        sweep_end_ray_index['data'] = seri

        # sweep_number
        sweep_number = filemetadata('sweep_number')
        sweep_number['data'] = np.arange(nsweeps, dtype='int32')

        # sweep_mode
        sweep_mode = filemetadata('sweep_mode')
        sweep_mode['data'] = np.array(nsweeps * ['azimuth_surveillance'])

        # scan_type
        if odim_object == 'ELEV':
            scan_type = 'rhi'
        else:
            scan_type = 'ppi'

        # fixed_angle
        fixed_angle = filemetadata('fixed_angle')
        if odim_object == 'ELEV':
            sweep_el = [hfile[d]['where'].attrs['az_angle'] for d in datasets]
        else:
            sweep_el = [hfile[d]['where'].attrs['elangle'] for d in datasets]
        fixed_angle['data'] = np.array(sweep_el, dtype='float32')

        # elevation
        elevation = filemetadata('elevation')
        if 'elangles' in ds1_how:
            edata = np.empty(total_rays, dtype='float32')
            for d, start, stop in zip(datasets, ssri, seri):
                edata[start:stop+1] = hfile[d]['how'].attrs['elangles'][:]
            elevation['data'] = edata
        elif odim_object == 'ELEV':
            edata = np.empty(total_rays, dtype='float32')
            for d, start, stop in zip(datasets, ssri, seri):
                edata[start:stop+1] = hfile[d]['where'].attrs['angles'][:]
            elevation['data'] = edata
        else:
            elevation['data'] = np.repeat(sweep_el, rays_per_sweep)

        # range
        _range = filemetadata('range')
        if 'rstart' in hfile['dataset1/where'].attrs:
            # derive range from rstart and rscale attributes if available

            # check that the gate spacing is constant between sweeps
            rstart = [hfile[d]['where'].attrs['rstart'] for d in datasets]
            if any(rstart != rstart[0]):
                raise ValueError('range start changes between sweeps')
            rscale = [hfile[d]['where'].attrs['rscale'] for d in datasets]
            if any(rscale != rscale[0]):
                raise ValueError('range scale changes between sweeps')
            all_sweeps_nbins = [hfile[d]['where'].attrs['nbins'] for d in datasets]
            # check for max range off all sweeps
            max_nbins = max(all_sweeps_nbins)

            if isinstance(max_nbins, np.ndarray):
                max_nbins = max_nbins[0]
            else:
                max_nbins = max(all_sweeps_nbins)

            rscenter = 1e3 * rstart[0] + rscale[0] / 2
            _range['data'] = np.arange(rscenter,
                                       rscenter + max_nbins * rscale[0],
                                       rscale[0], dtype='float32')
            _range['meters_to_center_of_first_gate'] = rstart[0] * 1000.
            _range['meters_between_gates'] = float(rscale[0])
        else:
            # if not defined use range attribute which defines the maximum range
            # in km. There is no information on the starting location of the
            # range bins so we assume this to be 0.
            # This most often occurs in RHI files, which technically do not meet
            # the ODIM 2.2 specs. Section 7.4 requires that these files include
            # the where/rstart, where/rscale and where/nbins attributes.
            max_range = [hfile[d]['where'].attrs['range'] for d in datasets]
            if any(max_range != max_range[0]):
                raise ValueError('maximum range changes between sweeps')
            # nbins is required
            nbins = hfile['dataset1/data1/data'].shape[1]
            _range['data'] = np.linspace(
                0, max_range[0] * 1000., nbins).astype('float32')
            _range['meters_to_center_of_first_gate'] = 0
            _range['meters_between_gates'] = max_range[0] * 1000. / nbins

        # azimuth
        azimuth = filemetadata('azimuth')
        az_data = np.ones((total_rays, ), dtype='float32')
        for dset, start, stop in zip(datasets, ssri, seri):
            if odim_object == 'ELEV':
                # all azimuth angles are the sweep azimuth angle
                sweep_az = hfile[dset]['where'].attrs['az_angle']
            elif odim_object == 'AZIM':
                # Sector azimuths are specified in the startaz and stopaz
                # attribute of dataset/where.
                # Assume that the azimuth angles do not pass through 0/360 deg.
                startaz = hfile[dset]['where'].attrs['startaz']
                stopaz = hfile[dset]['where'].attrs['stopaz']
                nrays = stop - start + 1
                sweep_az = np.linspace(startaz, stopaz, nrays, endpoint=True)
            elif ('startazA' in ds1_how) and ('stopazA' in ds1_how):
                # average between start and stop azimuth angles
                startaz = hfile[dset]['how'].attrs['startazA']
                stopaz = hfile[dset]['how'].attrs['stopazA']
                sweep_az = np.angle(
                    (np.exp(1.j*np.deg2rad(startaz)) +
                    np.exp(1.j*np.deg2rad(stopaz))) / 2., deg=True)
            else:
                # according to section 5.1 the first ray points to the
                # northernmost direction and proceeds clockwise for a complete
                # 360 rotation.
                try:
                    astart = hfile[dset]['how'].attrs['astart']
                except KeyError:
                    astart = 0.0
                nrays = hfile[dset]['where'].attrs['nrays']
                da = 360.0 / nrays
                sweep_az = np.arange(astart + da / 2., 360., da, dtype='float32')
            az_data[start:stop+1] = sweep_az
        azimuth['data'] = az_data

        # time
        _time = filemetadata('time')
        if ('startazT' in ds1_how) and ('stopazT' in ds1_how):
            # average between startazT and stopazT
            t_data = np.empty((total_rays, ), dtype='float32')
            for dset, start, stop in zip(datasets, ssri, seri):
                t_start = hfile[dset]['how'].attrs['startazT']
                t_stop = hfile[dset]['how'].attrs['stopazT']
                t_data[start:stop+1] = (t_start + t_stop) / 2
            start_epoch = t_data.min()
            start_time = datetime.datetime.utcfromtimestamp(start_epoch)
            _time['units'] = make_time_unit_str(start_time)
            _time['data'] = t_data - start_epoch
        else:
            t_data = np.empty((total_rays, ), dtype='int32')
            # interpolate between each sweep starting and ending time
            for dset, start, stop in zip(datasets, ssri, seri):
                dset_what = hfile[dset]['what'].attrs
                start_str = _to_str(
                    dset_what['startdate'] + dset_what['starttime'])
                end_str = _to_str(dset_what['enddate'] + dset_what['endtime'])
                start_dt = datetime.datetime.strptime(start_str, '%Y%m%d%H%M%S')
                end_dt = datetime.datetime.strptime(end_str, '%Y%m%d%H%M%S')

                time_delta = end_dt - start_dt
                delta_seconds = time_delta.seconds + time_delta.days * 3600 * 24
                rays = stop - start + 1
                sweep_start_epoch = (
                    start_dt - datetime.datetime(1970, 1, 1)).total_seconds()
                t_data[start:stop+1] = (sweep_start_epoch +
                                        np.linspace(0, delta_seconds, rays))
            start_epoch = t_data.min()
            start_time = datetime.datetime.utcfromtimestamp(start_epoch)
            _time['units'] = make_time_unit_str(start_time)
            _time['data'] = (t_data - start_epoch).astype('float32')

        # fields
        fields = {}
        h_field_keys = [k for k in hfile['dataset1'] if k.startswith('data')]
        odim_fields = [hfile['dataset1'][d]['what'].attrs['quantity'] for d in h_field_keys]
        for odim_field, h_field_key in zip(odim_fields, h_field_keys):
            field_name = filemetadata.get_field_name(_to_str(odim_field))
            if field_name is None:
                continue
            fdata = np.ma.zeros((total_rays, max_nbins), dtype='float32')
            start = 0
            # loop on the sweeps, copy data into correct location in data array
            for dset, rays_in_sweep in zip(datasets, rays_per_sweep):
                try:
                    sweep_data = _get_odim_h5_sweep_data(hfile[dset][h_field_key])
                except KeyError:
                    sweep_data = np.zeros((rays_in_sweep, max_nbins)) + np.NaN
                sweep_nbins = sweep_data.shape[1]
                fdata[start:start + rays_in_sweep, :sweep_nbins] = sweep_data[:]
                # set data to NaN if its beyond the range of this sweep
                fdata[start:start + rays_in_sweep, sweep_nbins:max_nbins] = np.nan
                start += rays_in_sweep
            # create field dictionary
            field_dic = filemetadata(field_name)
            field_dic['data'] = fdata
            field_dic['_FillValue'] = get_fillvalue()
            fields[field_name] = field_dic

    # instrument_parameters
    instrument_parameters = None

    return Radar(
        _time, _range, fields, metadata, scan_type,
        latitude, longitude, altitude,
        sweep_number, sweep_mode, fixed_angle, sweep_start_ray_index,
        sweep_end_ray_index,
        azimuth, elevation,
        instrument_parameters=instrument_parameters)



def _to_str(text):
    """ Convert bytes to str if necessary. """
    if hasattr(text, 'decode'):
        return text.decode('utf-8')
    else:
        return text


def _get_odim_h5_sweep_data(group):
    """ Get ODIM_H5 sweet data from an HDF5 group. """

    # mask raw data
    what = group['what']
    raw_data = group['data'][:]

    if 'nodata' in what.attrs:
        nodata = what.attrs.get('nodata')
        data = np.ma.masked_equal(raw_data, nodata)
    else:
        data = np.ma.masked_array(raw_data)
    if 'undetect' in what.attrs:
        undetect = what.attrs.get('undetect')
        data[data == undetect] = np.ma.masked
        
    offset = 0.0
    gain = 1.0
    if 'offset' in what.attrs:
        offset = what.attrs.get('offset')
    if 'gain' in what.attrs:
        gain = what.attrs.get('gain')
    return data * gain + offset

def _get_radar_name_from_radar_numer(radar_number):
    if radar_number==7:
        radar_name='Castor Bay'
    if radar_number==5:
        radar_name='Chenies'
    if radar_number==3:
        radar_name='Clee Hill'
    if radar_number==16:
        radar_name='Cobbacomebe Cross'
    if radar_number==10:
        radar_name='Crug-y-gorrllwyn'
    if radar_number==21:
        radar_name='Dean Hill'
    if radar_number==15:
        radar_name='Druim a\'Starraig'
    if radar_number==14:
        radar_name='Dudwick'
    if radar_number==4:
        radar_name='Hameldon Hill'
    if radar_number==23:
        radar_name='High Moorsley'
    if radar_number==18:
        radar_name='Holehead'
    if radar_number==9:
        radar_name='Ingham'
    if radar_number==12:
        radar_name='Jersey'
    if radar_number==19:
        radar_name='Munduff Hill'
    if radar_number==8:
        radar_name='Predannack'
    if radar_number==20:
        radar_name='Thurnham'
    if radar_number==11:
        radar_name='Wardon-hill'
    
    return radar_name

# %%
time='1700'
data_type='sp'

# %%
# %%time
radar=read_nimrod_aggregated_odim_h5(file,data_type, time)

# %%
excluded=np.where(np.logical_or((radar.fields['cross_correlation_ratio']['data'].data<0.2),(radar.fields['cross_correlation_ratio']['data'].data>0.9)))
radar.fields['cross_correlation_ratio']['data'].data[excluded]=np.nan

# %%
radar.fields['cross_correlation_ratio']['data'].data

# %% [markdown]
# # Plotting Function that uses the reading function above

# %%
def plot_ukmo_radar(fpath,data_type,time ,R,ele,plotpath, filter=False):
#Plotting Options Set in Function
#R = 50#  #Min and Mac Range from Radar in km


    #Read Files and Setup Plotting
    radar=read_nimrod_aggregated_odim_h5(fpath,data_type, time)
    if filter==True:
        alts=[]
        for e, e_val in enumerate(radar.fixed_angle['data']):
            lat, lon, alt= radar.get_gate_lat_lon_alt(e)
            if e==0:
                alts=alt
            else:
                alts=np.append(alts,alt,axis=0)
        excluded=np.where(np.logical_or(np.logical_or(np.logical_or(np.logical_or(
            np.logical_or((radar.fields['cross_correlation_ratio']['data'].data<0.25),(radar.fields['cross_correlation_ratio']['data'].data>0.9)),
            radar.fields['normalized_coherent_power']['data'].data<0.1),
            alts>2500),
            (radar.fields['differential_phase']['data'].data<5)),
            (radar.fields['normalized_coherent_power']['data'].data>0.8)) 
            )
        radar.fields['reflectivity']['data'].data[excluded]=np.nan
        radar.fields['differential_reflectivity']['data'].data[excluded]=np.nan
        radar.fields['cross_correlation_ratio']['data'].data[excluded]=np.nan
        radar.fields['differential_phase']['data'].data[excluded]=np.nan
        radar.fields['velocity']['data'].data[excluded]=np.nan
        radar.fields['normalized_coherent_power']['data'].data[excluded]=np.nan
    
    display = pyart.graph.RadarDisplay(radar)

    # set the figure title and show
    instrument_name = radar.metadata['instrument_name']
    time_start = netCDF4.num2date(radar.time['data'][0], radar.time['units'])
    time_text = ' ' + time_start.strftime('%Y-%m-%d %H:%M:%SZ')

    elevation = radar.fixed_angle['data'][ele]
    ele_text= '%0.1f' % (elevation)

    title = instrument_name + time_text + ' Elevation: '+ str(elevation) + ' Scan Type: '+data_type

 
    
    if np.round(elevation,0)>9.99:
        ele_folder ='ele'+ele_text[0]+ele_text[1]+'_'+ele_text[3]+ '/'
        ele_name= 'ele'+ele_text[0]+ele_text[1]+'_'+ele_text[3]
    else:
        ele_folder ='ele'+ele_text[0]+'_'+ele_text[2]+ '/'
        ele_name= 'ele'+ele_text[0]+'_'+ele_text[2]
        
    plot_file_name = instrument_name +'_'+ time_start.strftime('%Y-%m-%dT%H%M%SZ')+'_' +ele_name+'_'+data_type+ '.png'

    loc_folder = instrument_name+ '/'
    
    R_folder = str(R)+'km'+ '/'

    fig_save_file_path = plotpath+loc_folder+ ele_folder + R_folder

    #Figure Options
    width=15 #in inches
    height=7.5 #in inches

    fig = plt.figure(figsize=(width, height))
    nrows=2
    ncols=3

    ax1 = fig.add_subplot(nrows,ncols,1)
    display.plot('reflectivity',ele,ax=ax1, vmin=-32, vmax=45., title='Horizontal Reflectivity', colorbar_label=radar.fields['reflectivity']['units'],
                 axislabels=('', 'North South distance from radar (km)'))
    display.set_limits((-R, R), (-R, R), ax=ax1)

    
    ax2 = fig.add_subplot(nrows,ncols,2)
    display.plot('differential_reflectivity', ele,ax=ax2, vmin=-2, vmax=10., title='Differential Reflectivity', colorbar_label=radar.fields['differential_reflectivity']['units'],
                 axislabels=('', ''), cmap = 'pyart_RefDiff')
    display.set_limits((-R, R), (-R, R), ax=ax2)


    ax3 = fig.add_subplot(nrows,ncols,3)
    display.plot('cross_correlation_ratio', ele,ax=ax3, vmin=0.0, vmax=1.0, title='Cross Correlation Ratio', colorbar_label=radar.fields['cross_correlation_ratio']['units'],
                 axislabels=('', ''), cmap = 'pyart_RefDiff')
    display.set_limits((-R, R), (-R, R), ax=ax3)

    
    ax4 = fig.add_subplot(nrows,ncols,4)
    display.plot('velocity',ele,ax=ax4, vmin=-2, vmax=2., title='Doppler Velocity', colorbar_label=radar.fields['velocity']['units'],
                 axislabels=('East West distance from radar (km)', 'North South distance from radar (km)'), cmap = 'pyart_BuDRd18')
    display.set_limits((-R, R), (-R, R), ax=ax4)
    
    
    ax5 = fig.add_subplot(nrows,ncols,5)
    display.plot('differential_phase', ele,ax=ax5, vmin=-5, vmax=120., title='Differential Phase', colorbar_label=radar.fields['differential_phase']['units'],
                 axislabels=('East West distance from radar (km)', ''), cmap = 'pyart_Wild25')
    display.set_limits((-R, R), (-R, R), ax=ax5)

    
    #ax6 = fig.add_subplot(nrows,ncols,6)
    #display.plot('spectrum_width', ele, ax=ax6, vmin=0, vmax=5., title='Spectrum Width', colorbar_label=radar.fields['spectrum_width']['units'],
    #             axislabels=('East West distance from radar (km)', ''), cmap = 'pyart_NWS_SPW')
    #display.set_limits((-R, R), (-R, R), ax=ax6)

    
    ax6 = fig.add_subplot(nrows,ncols,6)
    display.plot('normalized_coherent_power', ele, ax=ax6, title='Normalized Coherent Power', colorbar_label=radar.fields['normalized_coherent_power']['units'],
                 axislabels=('East West distance from radar (km)', ''), cmap = 'pyart_Carbone17')
    
    display.set_limits((-R, R), (-R, R), ax=ax6)

    plt.suptitle(title, fontsize=24)
    
    
    if not os.path.exists(fig_save_file_path):
        os.makedirs(fig_save_file_path)
    if filter==True:
        plot_file_name=plot_file_name[0:-3]+'_filtered.png'
    plt.savefig(fig_save_file_path+plot_file_name, dpi=100)
    
    plt.close()
    
    del radar
    del display

# %%
time='1200'
data_type='lp'
R=50
Wele=4
plotpath='~/test'
filter=[True, False]
ele=[0,1,2,3,4]
for f in filter:
    for e in ele:
        plot_ukmo_radar(file,data_type,time ,R,e,plotpath,filter=f)
